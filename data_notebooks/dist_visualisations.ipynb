# %%
import sys
sys.path.append('../')
import matplotlib.pyplot as plt
import numpy as np

from data_generation import simple_generation

# %%
a = simple_generation(0, 1,1000000)
plt.hist(a.init_dist)
# Out:
# (array([7.30000e+01, 2.46500e+03, 2.96690e+04, 1.53552e+05, 3.40545e+05,
#         3.20518e+05, 1.29380e+05, 2.22270e+04, 1.52300e+03, 4.80000e+01]),
#  array([-4.72770299, -3.7691445 , -2.81058602, -1.85202753, -0.89346905,
#          0.06508944,  1.02364793,  1.98220641,  2.9407649 ,  3.89932339,
#          4.85788187]),
#  <BarContainer object of 10 artists>)

# %%
quad_array = a.quad_fit()
plt.hist(quad_array)
# Out:
# (array([3.00000e+00, 9.00000e+00, 3.20000e+01, 1.12000e+02, 4.38000e+02,
#         1.47800e+03, 5.64700e+03, 2.22880e+04, 9.46070e+04, 8.75386e+05]),
#  array([-12.71844668, -11.53849587, -10.35854505,  -9.17859424,
#          -7.99864342,  -6.81869261,  -5.63874179,  -4.45879098,
#          -3.27884016,  -2.09888935,  -0.91893853]),
#  <BarContainer object of 10 artists>)

# %%
lin = a.linear_fit()
plt.hist(lin)
# Out:
# (array([3.73129e+05, 2.95300e+05, 1.86496e+05, 9.28250e+04, 3.70670e+04,
#         1.16320e+04, 2.86900e+03, 5.85000e+02, 8.70000e+01, 1.00000e+01]),
#  array([1.30331931e-07, 3.43504239e-01, 6.87008347e-01, 1.03051246e+00,
#         1.37401656e+00, 1.71752067e+00, 2.06102478e+00, 2.40452889e+00,
#         2.74803300e+00, 3.09153711e+00, 3.43504122e+00]),
#  <BarContainer object of 10 artists>)

# %%
x = a.init_dist
y = a.quad_fit()
plt.plot(x, y, ".")

# %%
b = a.linear_fit()
c = a.c_return()

d = b**2

plt.plot(x, b, ".")
plt.figure()
plt.plot(x,-d,'.')

# %%
plt.plot(x, np.exp(-d), ".")

# %%
plt.hist(np.exp(-d))
# Out:
# (array([ 32099.,  40917.,  47835.,  54953.,  63807.,  72868.,  86044.,
#         105852., 141369., 354256.]),
#  array([7.50824995e-06, 1.00006757e-01, 2.00006007e-01, 3.00005256e-01,
#         4.00004505e-01, 5.00003754e-01, 6.00003003e-01, 7.00002252e-01,
#         8.00001502e-01, 9.00000751e-01, 1.00000000e+00]),
#  <BarContainer object of 10 artists>)
